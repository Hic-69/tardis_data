# %% [markdown]
# # TARDIS — Modèle de prédiction (Étape 3)

# %%
# TODO: chargement de cleaned_dataset.csv

# %%
# TODO: feature engineering (encodage catégoriel, features temporelles)

# %%
# TODO: split train/test + baseline

# %%
# TODO: entraînement de 2-3 modèles (linéaire + arbres)

# %%
# TODO: évaluation (RMSE, MAE, R²) et comparaison

# %%
# TODO: tuning d'hyperparamètres du meilleur modèle

# %% [markdown]
# TODO: justification du modèle retenu

# %%
# TODO: sauvegarde -> model.joblib
